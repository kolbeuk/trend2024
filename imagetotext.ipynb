# %%
import pytesseract
import concurrent.futures
import os

# %%
def process_image_to_text(image_file):
    # Perform OCR on the image
    extracted_text = pytesseract.image_to_string(image_file)

    # Define the output text file path using the image file name
    text_file_path = os.path.splitext(image_file)[0] + '.txt'

    # Save the extracted text to a text file in the same directory as the image
    with open(text_file_path, 'w', encoding='utf-8') as text_file:
        text_file.write(extracted_text)

    print(f'Extracted text from image {image_file} and saved it to {text_file_path}')

# %%
def main():
    # Directory containing the saved images
    image_dir = 'extracted_images'

    # List of image files with '.png' extension
    image_files = [os.path.join(image_dir, image_file) for image_file in os.listdir(image_dir) if image_file.endswith('.png')]

    # Number of maximum workers
    max_workers = 12

    # Create a ThreadPoolExecutor with the specified maximum workers
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit the image processing tasks in parallel
        executor.map(process_image_to_text, image_files)

    print('Text has been extracted from the images and saved as text files in the same directory as the images.')

if __name__ == "__main__":
    main()
# Out:
# Extracted text from image extracted_images/image_17.png and saved it to extracted_images/image_17.txt
# Extracted text from image extracted_images/image_14.png and saved it to extracted_images/image_14.txt
# Extracted text from image extracted_images/image_11.png and saved it to extracted_images/image_11.txt
# Extracted text from image extracted_images/image_29.png and saved it to extracted_images/image_29.txt
# Extracted text from image extracted_images/image_38.png and saved it to extracted_images/image_38.txt
# Extracted text from image extracted_images/image_39.png and saved it to extracted_images/image_39.txt
# Extracted text from image extracted_images/image_12.png and saved it to extracted_images/image_12.txt
# Extracted text from image extracted_images/image_15.png and saved it to extracted_images/image_15.txt
# Extracted text from image extracted_images/image_62.png and saved it to extracted_images/image_62.txt
# Extracted text from image extracted_images/image_8.png and saved it to extracted_images/image_8.txt
# Extracted text from image extracted_images/image_13.png and saved it to extracted_images/image_13.txtExtracted text from image extracted_images/image_10.png and saved it to extracted_images/image_10.txt
# Extracted text from image extracted_images/image_48.png and saved it to extracted_images/image_48.txt
#
# Extracted text from image extracted_images/image_16.png and saved it to extracted_images/image_16.txt
# Extracted text from image extracted_images/image_63.png and saved it to extracted_images/image_63.txt
# Extracted text from image extracted_images/image_28.png and saved it to extracted_images/image_28.txt
# Extracted text from image extracted_images/image_49.png and saved it to extracted_images/image_49.txt
# Extracted text from image extracted_images/image_61.png and saved it to extracted_images/image_61.txt
# Extracted text from image extracted_images/image_9.png and saved it to extracted_images/image_9.txt
# Extracted text from image extracted_images/image_60.png and saved it to extracted_images/image_60.txt
# Extracted text from image extracted_images/image_65.png and saved it to extracted_images/image_65.txt
# Extracted text from image extracted_images/image_74.png and saved it to extracted_images/image_74.txt
# Extracted text from image extracted_images/image_58.png and saved it to extracted_images/image_58.txt
# Extracted text from image extracted_images/image_57.png and saved it to extracted_images/image_57.txt
# Extracted text from image extracted_images/image_64.png and saved it to extracted_images/image_64.txt
# Extracted text from image extracted_images/image_70.png and saved it to extracted_images/image_70.txt
# Extracted text from image extracted_images/image_71.png and saved it to extracted_images/image_71.txt
# Extracted text from image extracted_images/image_66.png and saved it to extracted_images/image_66.txt
# Extracted text from image extracted_images/image_43.png and saved it to extracted_images/image_43.txt
# Extracted text from image extracted_images/image_72.png and saved it to extracted_images/image_72.txt
# Extracted text from image extracted_images/image_73.png and saved it to extracted_images/image_73.txt
# Extracted text from image extracted_images/image_67.png and saved it to extracted_images/image_67.txtExtracted text from image extracted_images/image_59.png and saved it to extracted_images/image_59.txt
#
# Extracted text from image extracted_images/image_68.png and saved it to extracted_images/image_68.txtExtracted text from image extracted_images/image_42.png and saved it to extracted_images/image_42.txt
#
# Extracted text from image extracted_images/image_56.png and saved it to extracted_images/image_56.txt
# Extracted text from image extracted_images/image_54.png and saved it to extracted_images/image_54.txt
# Extracted text from image extracted_images/image_1.png and saved it to extracted_images/image_1.txt
# Extracted text from image extracted_images/image_3.png and saved it to extracted_images/image_3.txt
# Extracted text from image extracted_images/image_2.png and saved it to extracted_images/image_2.txt
# Extracted text from image extracted_images/image_4.png and saved it to extracted_images/image_4.txt
# Extracted text from image extracted_images/image_51.png and saved it to extracted_images/image_51.txt
# Extracted text from image extracted_images/image_45.png and saved it to extracted_images/image_45.txt
# Extracted text from image extracted_images/image_5.png and saved it to extracted_images/image_5.txt
# Extracted text from image extracted_images/image_55.png and saved it to extracted_images/image_55.txt
# Extracted text from image extracted_images/image_44.png and saved it to extracted_images/image_44.txt
# Extracted text from image extracted_images/image_40.png and saved it to extracted_images/image_40.txt
# Extracted text from image extracted_images/image_69.png and saved it to extracted_images/image_69.txt
# Extracted text from image extracted_images/image_7.png and saved it to extracted_images/image_7.txt
# Extracted text from image extracted_images/image_52.png and saved it to extracted_images/image_52.txt
# Extracted text from image extracted_images/image_50.png and saved it to extracted_images/image_50.txt
# Extracted text from image extracted_images/image_35.png and saved it to extracted_images/image_35.txt
# Extracted text from image extracted_images/image_20.png and saved it to extracted_images/image_20.txt
# Extracted text from image extracted_images/image_21.png and saved it to extracted_images/image_21.txt
# Extracted text from image extracted_images/image_41.png and saved it to extracted_images/image_41.txt
# Extracted text from image extracted_images/image_46.png and saved it to extracted_images/image_46.txt
# Extracted text from image extracted_images/image_6.png and saved it to extracted_images/image_6.txt
# Extracted text from image extracted_images/image_47.png and saved it to extracted_images/image_47.txt
# Extracted text from image extracted_images/image_53.png and saved it to extracted_images/image_53.txt
# Extracted text from image extracted_images/image_23.png and saved it to extracted_images/image_23.txt
# Extracted text from image extracted_images/image_32.png and saved it to extracted_images/image_32.txt
# Extracted text from image extracted_images/image_36.png and saved it to extracted_images/image_36.txt
# Extracted text from image extracted_images/image_34.png and saved it to extracted_images/image_34.txt
# Extracted text from image extracted_images/image_26.png and saved it to extracted_images/image_26.txt
# Extracted text from image extracted_images/image_19.png and saved it to extracted_images/image_19.txt
# Extracted text from image extracted_images/image_27.png and saved it to extracted_images/image_27.txt
# Extracted text from image extracted_images/image_33.png and saved it to extracted_images/image_33.txt
# Extracted text from image extracted_images/image_37.png and saved it to extracted_images/image_37.txt
# Extracted text from image extracted_images/image_31.png and saved it to extracted_images/image_31.txt
# Extracted text from image extracted_images/image_22.png and saved it to extracted_images/image_22.txt
# Extracted text from image extracted_images/image_24.png and saved it to extracted_images/image_24.txt
# Extracted text from image extracted_images/image_30.png and saved it to extracted_images/image_30.txt
# Extracted text from image extracted_images/image_25.png and saved it to extracted_images/image_25.txt
# Extracted text from image extracted_images/image_18.png and saved it to extracted_images/image_18.txt
# Text has been extracted from the images and saved as text files in the same directory as the images.
